# %%
from fastai.gen_doc.nbdoc import *

# %%
jekyll_note('To get started with fastai, have a look at the <a href="/training">training overview</a>. The documentation below covers some lower-level details.')
# Out:
# <div markdown="span" class="alert alert-info" role="alert"><i class="fa fa-info-circle"></i> <b>Note: </b>To get started with fastai, have a look at the <a href="/training">training overview</a>. The documentation below covers some lower-level details.</div>

# %% [markdown]
# ## módulos principais de fastai

# %% [markdown]
# Os fundamentos básicos necessários em várias partes da biblioteca são fornecidos por estes módulos:

# %% [markdown]
# ## xX_ markdown_link _xx
# Este módulo define a classe [`DataBunch`](/basic_data.html#DataBunch) básico, que é o que será necessário para criar um objeto [`Learner`](/basic_train.html#Learner) com um modelo. Ele também define o [`DeviceDataLoader`](/basic_data.html#DeviceDataLoader), uma classe que envolve um [`DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) pytorch para colocar lotes no dispositivo certo.

# %% [markdown]
# ## xX_ markdown_link _xx
# Este módulo contém as definições das camadas personalizadas básicas que precisamos na maioria dos nossos modelos, bem como algumas funções auxiliares para criar blocos simples.

# %% [markdown]
# A maioria da documentação dos dois módulos seguintes pode ser ignorada em uma primeira leitura, a menos que você quer especificamente para saber o que uma determinada função está fazendo.

# %% [markdown]
# ## xX_ markdown_link _xx
# Este módulo contém as funções mais básicas e as importações, nomeadamente:
# - pandas as pd
# - numpy como np
# - matplotlib.pyplot as plt

# %% [markdown]
# ## xX_ markdown_link _xx
# Este módulo contém as funções mais básicas e importações que usam pytorch. Seguimos convenções de nomenclatura pytorch, principalmente:
# - torch.nn como nn
# - torch.optim como óptima
# - torch.nn.functional como F

# %% [markdown]
# ## Uso

# %% [markdown]
# módulos principais são [designed](/index.html#imports) para ser em conjunto com [application](/applications.html#Usage) módulos específicos e importados automaticamente nesses casos.

# %% [markdown]
# Para importar funcionalidade do núcleo * only *:

# %%
from fastai.basics import *
