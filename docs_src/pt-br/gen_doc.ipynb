# %% [markdown]
# ## Módulos para manter docs

# %%
from fastai.gen_doc.nbdoc import *
from fastai.gen_doc.gen_notebooks import *
from fastai.gen_doc import *

# %% [markdown]
# A documentação é construído a partir de notebooks em `docs_src /` e `arquivos .md` em` docs / `.
# Para gerar e cadernos autor, e construir a documentação, consulte [these instructions](/gen_doc_main.html), bem como [`fastai.gen_doc.gen_notebooks`](/gen_doc.gen_notebooks.html#gen_doc.gen_notebooks).

# %% [markdown]
# ## módulos

# %% [markdown]
# ### xX_ markdown_link _xx

# %% [markdown]
# Gerar e esqueletos atualização notebook automaticamente de módulos. Inclui uma visão geral de todo o processo de criação.

# %% [markdown]
# ### xX_ markdown_link _xx

# %% [markdown]
# Criar docs de cadernos HTML (Jekyll).

# %% [markdown]
# ### xX_ markdown_link _xx

# %% [markdown]
# Subjacentes às funções de documentação; mais importante é [`show_doc`](/gen_doc.nbdoc.html#show_doc).
