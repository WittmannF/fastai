# %% [markdown]
# ## campos de aplicação

# %%
from fastai.gen_doc.nbdoc import *

# %% [markdown]
# A biblioteca fastai permite treinar um [`Model`](https://pytorch.org/docs/stable/nn.html#torch.nn.Module) em um determinado [`DataBunch`](/basic_data.html#DataBunch) muito facilmente através da ligação-los juntos dentro de um objeto [`Learner`](/basic_train.html#Learner). Este módulo agrupa as ferramentas da biblioteca fornece para ajudá-lo pré-processar e agrupar seus dados nesse formato.
# ## xX_ markdown_link _xx
# Este sub-módulo lida com os problemas de filtragem colaborativa.
# ## xX_ markdown_link _xx
# Esta sub-pacote lida com tabular (ou estruturados) de dados.
# ## xX_ markdown_link _xx
# Esta sub-pacote contém tudo que você precisa para processamento de linguagem natural.
# ## xX_ markdown_link _xx
# Esta sub-pacote contém as classes que lidam com Computer Vision.

# %% [markdown]
# ## estrutura Módulo
# Em cada caso (exceto para [`collab`](/collab.html#collab)), o módulo está organizado da seguinte forma:
# ### xX_ markdown_link _xx
# Esta sub-módulo trata com o pré-processamento (de aumento de dados de imagens, dados de limpeza para tabulares, tokenizing e numericalizing para o texto).
# ### xX_ markdown_link _xx
# Esta sub-módulo define a classe dataset (es) para lidar com este tipo de dados.
# ### xX_ markdown_link _xx
# Esta sub-módulo define os modelos específicos utilizados para este tipo de dados.
# ### xX_ markdown_link _xx
# Quando se existir, este sub-módulo contém funções que se irão ligar directamente estes dados com um modelo adequado e adicionar as chamadas de retorno necessárias.

# %% [markdown]
# ## uso
# Para começar a usar qualquer um dos aplicativos acima, simplesmente importar o módulo de nível superior.
# Todos os [submodules](#Module-structure) são incluídos.

# %% [markdown]
# A estrutura geral é:
# ```python
# from fastai.[APPLICATION] import *
# ```

# %% [markdown]
# Por exemplo, para usar collab:
# ```python
# from fastai.collab import *
# ```

# %% [markdown]
# * Para mais informações sobre [imports](/index.html#imports) *

# %% [markdown]
# ## Abra Este Notebook
# <Style botão = "display: flexionar; alinhar item: center; padding: 4px 8px; font-size: 14px; font-weight: 700; color: # 1976d2; cursor: pointer;" onclick = "window.location.href = 'https://console.cloud.google.com/mlengine/notebooks/deploy-notebook?q=download_url%3Dhttps%253A%252F%252Fraw.githubusercontent.com%252Ffastai%252Ffastai% 252Fmaster% 252Fdocs_src% 252Fapplications.ipynb '; "> <img src =" https://www.gstatic.com/images/branding/product/1x/cloud_24dp.png "/> <span style =" line-height: 24px ; margin-left: 10px; "> Open in Notebooks GCP </ span> </ button>
